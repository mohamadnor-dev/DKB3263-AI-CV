# %% [markdown]
# <a href="https://colab.research.google.com/github/mohamadnor-dev/DKB3263-AI-CV/blob/main/Ulangkaji_topik2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib as plt
import pandas as pd


nama_pelajar =["Azlan","Awang","Tasnim"]

markah_ujian1 =[50,60,40]
markah_ujian2 =[40,70,80]
markah_ujian3 =[80,40,70]
